# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

#from tensorflow.data.Dataset import load
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pandas as pd

import os
from file_helpers import unpickle_from_file
# Out:
# 2024-03-11 03:19:10.981908: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_labels_sorted = unpickle_from_file('../data/processed_data/train_labels_sorted.bin')

# %%
#Read training data
batch_size = 32
img_height = 227
img_width = 227

train_ds = tf.keras.utils.image_dataset_from_directory(
  '../data/processed_data/training_images',
  validation_split=0.15,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
labels = train_labels_sorted)
# Out:
# Found 51957 files belonging to 8 classes.
# Using 44164 files for training.
# 2024-03-11 03:19:16.399331: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
#Read validation data

val_ds = tf.keras.utils.image_dataset_from_directory(
  '../data/processed_data/training_images',
  validation_split=0.15,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
labels = train_labels_sorted)
# Out:
# Found 51957 files belonging to 8 classes.
# Using 7793 files for validation.

# %%
#Try to keep things in memory for performance reasons
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
img_height = 227
img_width = 227

num_classes = 8

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10

#Silence debug messages for cleaner output
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

history = model.fit(
  train_ds,
  validation_data = val_ds,
  epochs = epochs
)
# Out:
# Epoch 1/10
# 2024-03-11 03:19:19.828529: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [44164]
# 	 [[{{node Placeholder/_0}}]]
# 2024-03-11 03:19:19.829157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [44164]
# 	 [[{{node Placeholder/_0}}]]
# 1381/1381 [==============================] - ETA: 0s - loss: 0.6333 - accuracy: 0.8317
# 2024-03-11 03:59:55.712825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [7793]
# 	 [[{{node Placeholder/_0}}]]
# 2024-03-11 03:59:55.714228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [7793]
# 	 [[{{node Placeholder/_4}}]]
# 1381/1381 [==============================] - 2486s 2s/step - loss: 0.6333 - accuracy: 0.8317 - val_loss: 1.1592 - val_accuracy: 0.7789
# Epoch 2/10
# 1381/1381 [==============================] - 2285s 2s/step - loss: 0.4454 - accuracy: 0.8680 - val_loss: 1.2992 - val_accuracy: 0.7454
# Epoch 3/10
# 1381/1381 [==============================] - 2286s 2s/step - loss: 0.3251 - accuracy: 0.8979 - val_loss: 1.6487 - val_accuracy: 0.7265
# Epoch 4/10
# 1381/1381 [==============================] - 2313s 2s/step - loss: 0.2215 - accuracy: 0.9290 - val_loss: 2.2411 - val_accuracy: 0.7283
# Epoch 5/10
# 1381/1381 [==============================] - 2314s 2s/step - loss: 0.1426 - accuracy: 0.9519 - val_loss: 2.8617 - val_accuracy: 0.6875
# Epoch 6/10
# 1381/1381 [==============================] - 2367s 2s/step - loss: 0.0871 - accuracy: 0.9709 - val_loss: 3.0668 - val_accuracy: 0.6932
# Epoch 7/10
# 1381/1381 [==============================] - 2334s 2s/step - loss: 0.0621 - accuracy: 0.9794 - val_loss: 4.2686 - val_accuracy: 0.7145
# Epoch 8/10
# 1381/1381 [==============================] - 2341s 2s/step - loss: 0.0482 - accuracy: 0.9843 - val_loss: 5.0951 - val_accuracy: 0.7122
# Epoch 9/10
# 1381/1381 [==============================] - 2300s 2s/step - loss: 0.0381 - accuracy: 0.9875 - val_loss: 5.3051 - val_accuracy: 0.7074
# Epoch 10/10
# 1381/1381 [==============================] - 2360s 2s/step - loss: 0.0358 - accuracy: 0.9887 - val_loss: 5.1987 - val_accuracy: 0.7085

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model_2 = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.4),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model_2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10

history_2 = model_2.fit(
  train_ds,
  validation_data = val_ds,
  epochs = epochs
)
# Out:
# Epoch 1/10
# 1381/1381 [==============================] - 2306s 2s/step - loss: 0.6466 - accuracy: 0.8298 - val_loss: 1.1602 - val_accuracy: 0.7629
# Epoch 2/10
# 1381/1381 [==============================] - 2342s 2s/step - loss: 0.4618 - accuracy: 0.8650 - val_loss: 1.4445 - val_accuracy: 0.7290
# Epoch 3/10
# 1381/1381 [==============================] - 2329s 2s/step - loss: 0.3584 - accuracy: 0.8877 - val_loss: 1.6881 - val_accuracy: 0.7373
# Epoch 4/10
# 1381/1381 [==============================] - 2365s 2s/step - loss: 0.2651 - accuracy: 0.9137 - val_loss: 1.7278 - val_accuracy: 0.7164
# Epoch 5/10
# 1381/1381 [==============================] - 2330s 2s/step - loss: 0.1936 - accuracy: 0.9346 - val_loss: 2.5538 - val_accuracy: 0.7063
# Epoch 6/10
# 1381/1381 [==============================] - 2322s 2s/step - loss: 0.1482 - accuracy: 0.9499 - val_loss: 2.6718 - val_accuracy: 0.6981
# Epoch 7/10
# 1381/1381 [==============================] - 2343s 2s/step - loss: 0.1129 - accuracy: 0.9609 - val_loss: 2.9857 - val_accuracy: 0.6927
# Epoch 8/10
# 1381/1381 [==============================] - 2326s 2s/step - loss: 0.0857 - accuracy: 0.9703 - val_loss: 3.7112 - val_accuracy: 0.7189
# Epoch 9/10
# 1381/1381 [==============================] - 2288s 2s/step - loss: 0.0748 - accuracy: 0.9754 - val_loss: 3.7872 - val_accuracy: 0.7050
# Epoch 10/10
# 1381/1381 [==============================] - 2481s 2s/step - loss: 0.0620 - accuracy: 0.9787 - val_loss: 4.3765 - val_accuracy: 0.7189

# %%
acc = history_2.history['accuracy']
val_acc = history_2.history['val_accuracy']

loss = history_2.history['loss']
val_loss = history_2.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
